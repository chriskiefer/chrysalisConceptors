# %%
# loads numpy and matplotlib
# %pylab inline

# imports functions to interact with operating system
import os

import scipy as sp
from numba import jit
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#plot(np.tanh(np.random.randn(10)))
def makeRandomWalk(len):
    pt = zeros(len)
    pt[0] = np.random.randn(1)
    for n in range(pt.size-1):
        pt[n+1] = pt[n] + np.random.randn(1)
    pt = pt - np.min(pt)
    pt = (pt / np.max(pt) * 2) - 1
    return pt
    

#plot()
pattern1 = makeRandomWalk(20)
pattern2 = makeRandomWalk(20)

# %%
plot(pattern1)
plot(pattern2)

# %%
# get current working path
cwd = os.getcwd()
print( cwd )

# load gesture 1
gesture1 = np.loadtxt(cwd + '/gesturedata_0.txt')
gesture2 = np.loadtxt(cwd + '/gesturedata_1.txt')

# plot the two gestures
figsize(20,8);

plot( gesture1 )
plot( gesture2 )
# Out:
# /Volumes/LocalDataHD/virtualenvs/env3/chrysalisConceptors/workshop

# %%
figsize(20,5)
# to normalize the two gestures to each other, we find the maximum value in the two arrays:
maxValue = max( max(gesture1), max(gesture2) )

print( maxValue )

# scale the gestures and make bipolar:

gesture1 = (gesture1 / maxValue)*2 - 1;
gesture2 = (gesture2 / maxValue)*2 - 1;

# plot it again: looks the same, but scale on the y-axis is now between -1 and 1
plot( gesture1 )
plot( gesture2 )
# Out:
# 0.0516839488978

# %%
#define some useful functions
@jit
def nrmse(output,target):
    combinedVar = 0.5 * (np.var(target, ddof=1) + np.var(output, ddof=1))
    errorSignal = output - target
    return np.sqrt(np.mean(errorSignal ** 2) / combinedVar)

def generateInternalWeights(nInternalUnits, connectivity):
    success = False
    internalWeights = 0
    while success == False:
        try:
            internalWeights = np.random.randn(nInternalUnits,nInternalUnits) * (np.random.random((nInternalUnits,nInternalUnits)) < connectivity)
            specRad = abs(np.linalg.eig(internalWeights)[0][0])
            if (specRad > 0):
                internalWeights = internalWeights / specRad
                success = True
        except e:
            print(e)
    return internalWeights

pLoop = lambda n,p: p[n%p.size]

# %%
def makeClassifierNetwork(p):
    Netconnectivity = 1
    if p['N'] > 20:
        Netconnectivity = 10.0/p['N'];
    WstarRaw = generateInternalWeights(p['N'], Netconnectivity)
    WinRaw = 2 * (np.random.rand(p['N'], 1) - 0.5)
    WbiasRaw = 2 * (np.random.rand(p['N'], 1) - 0.5)

    #Scale raw weights     
    Wstar = p['NetSR'] * WstarRaw;
    W = Wstar
    Win = p['NetinpScaling'] * WinRaw;
    Wbias = p['BiasScaling'] * WbiasRaw;  
    I = np.eye(p['N'])
    xCollector = np.zeros((p['N'], p['learnLength']))
    pCollector = np.zeros((1, p['learnLength']))
    x = np.zeros((p['N'],1))
    
    allTrainxArgs = np.zeros((p['N'] + 1, 0));
    allTrainOldxArgs = np.zeros((p['N'], 0));
    allTrainWtargets = np.zeros((p['N'], 0));
    allTrainOuts = np.zeros((1, 0));
    patternRs =  np.zeros((1, p['patts'].size), dtype=np.object)
    
    for i_pattern in range(p['patts'].size):
        print('Observing pattern ', i_pattern)
        patt = p['patts'][i_pattern]
        xCollector = np.zeros((p['N'] + 1, p['learnLength']));
        xOldCollector = np.zeros((p['N'], p['learnLength']));
        WTargetCollector = np.zeros((p['N'], p['learnLength']));
        pCollector = np.zeros((1, p['learnLength']));
        x = np.zeros((p['N'], 1));

        for n in range(p['washoutLength'] + p['learnLength']):
            u = patt(n+1)
            xOld = x
            Wtarget = (Wstar.dot(x)) + (Win.dot(u))
            x = ((1.0-p['LR']) * xOld) + (p['LR'] * tanh(Wtarget + Wbias))
            if n >= p['washoutLength']:
                xCollector[:, n - p['washoutLength']] = np.concatenate((x[:,0], np.array([1])))
                xOldCollector[:, n - p['washoutLength']] = xOld[:,0]
                WTargetCollector[:, n - p['washoutLength']] = Wtarget[:,0]
                pCollector[0, n - p['washoutLength']] = u
            uOld = u
        
        R = xCollector[0:-1].dot(xCollector[0:-1].T) / p['learnLength']
        patternRs[0,i_pattern] = R
        allTrainxArgs = np.concatenate((allTrainxArgs, xCollector), axis=1)
        allTrainOldxArgs = np.concatenate((allTrainOldxArgs, xOldCollector), axis=1)
        allTrainOuts = np.concatenate((allTrainOuts, pCollector), axis=1)
        allTrainWtargets = np.concatenate((allTrainWtargets, WTargetCollector), axis=1)

    return locals()



params = {'N':10, 'NetSR':1.9, 'NetinpScaling':1,'BiasScaling':0.6,
         'washoutLength':300, 'learnLength':40, 
          'LR': 1.0,
#           'patts':np.array([lambda x:pLoop(x,p_rw1), lambda x: pLoop(x,p_rw2)])
          'patts':np.array([lambda x:pLoop(x,pattern1), lambda x: pLoop(x,pattern2)])
         }

net = makeClassifierNetwork(params)
# Out:
# Observing pattern  0
# Observing pattern  1

# %%
figsize(20,8)
plot(net['allTrainxArgs'].T)
None

# %%
#define functions to compute and test the conceptors

def computeConceptors(p, net, alphas):
    print('Computing conceptors, alphas: ', alphas)
    Cs = np.zeros((4, p['patts'].size), dtype=np.object)
    for i_pattern in range(p['patts'].size):
        R = net['patternRs'][0,i_pattern]
        [U,s,V] = svd(R)
        S = diag(s)
        Snew = (S * linalg.inv(S + pow(alphas[i_pattern], -2) * np.eye(p['N'])))

        C =  U.dot(Snew).dot(U.T);
        Cs[0,i_pattern] = C
        Cs[1,i_pattern] = U
        Cs[2,i_pattern] = diag(Snew)
        Cs[3,i_pattern] = diag(S)
    return locals()

import scipy.spatial.distance as dist


def plotConceptorPatterns(p, cNet, subr, suboff, recallTestLength):
    x_CTestPL = np.zeros((3, recallTestLength, p['patts'].size))
    p_CTestPL = np.zeros((1, recallTestLength, p['patts'].size))
    cx_CTestPL = np.zeros((p['patts'].size,recallTestLength))
    pat_CTestPL = np.zeros((1,recallTestLength))
    
    for i_pattern in range(p['patts'].size):
        patt = p['patts'][i_pattern]
        x = np.zeros((p['N'],1))
        for n in range(recallTestLength + p['washoutLength']):
            u = patt(n+1)
            xOld = x
            Wtarget = (cNet['net']['W'].dot(x)) + (cNet['net']['Win'].dot(u))
            x = ((1.0-p['LR']) * xOld) + (p['LR'] * tanh(Wtarget + cNet['net']['Wbias']))
            if (n > p['washoutLength']):
                pat_CTestPL[0,n-p['washoutLength'] ] = u
                C = cNet['Cs'][0,0]
                C2 = cNet['Cs'][0,1]
                cx = x.T.dot(C.dot(x)) + x.T.dot((1.0-C2).dot(x))
                cx_CTestPL[0,n-p['washoutLength']] = cx
                cx2 = x.T.dot(C2.dot(x)) + x.T.dot((1.0-C).dot(x))
#                 cx2 = x.T.dot(C2.dot(x))
                cx_CTestPL[1,n-p['washoutLength']] = cx2

        ax = subplot(subr, 2, suboff + i_pattern + 1)
        ax.set_title("Sample " + str(suboff/2) + ", pattern: " + str(i_pattern) + ", alphas: " + str(cNet['alphas']))
#         plot([p['patts'][i_pattern](x) for x in arange(recallTestLength)])
        plot(pat_CTestPL.T)
        plot(cx_CTestPL.T)
        classificationScore = np.sum(cx_CTestPL[i_pattern] > cx_CTestPL[1 - i_pattern]) / cx_CTestPL[0].size
        separation = dist.euclidean(cx_CTestPL[i_pattern],cx_CTestPL[1-i_pattern])
        print("Pattern ", str(i_pattern), " classification score: ", classificationScore, ", separation: ", separation)
        #testing

    return locals()

# %%
conceptorSampleSize = 20
conceptorNets = np.zeros(conceptorSampleSize, dtype=np.object)
figsize(15,conceptorSampleSize * 1.9)
for i_cnet in range(conceptorSampleSize):
    conceptorNets[i_cnet] = computeConceptors(params, net, np.random.random(2) * 100)
    pq = plotConceptorPatterns(params, conceptorNets[i_cnet], conceptorSampleSize, i_cnet * 2, 100)
plt.tight_layout();
# Out:
# Computing conceptors, alphas:  [ 63.66368182  72.61553894]
# Pattern  0  classification score:  0.99 , separation:  8.590415201521568
# Pattern  1  classification score:  0.99 , separation:  5.582862917489858
# Computing conceptors, alphas:  [ 14.1450491   59.72003876]
# Pattern  0  classification score:  0.99 , separation:  8.249159453434165
# Pattern  1  classification score:  0.99 , separation:  10.403199188705145
# Computing conceptors, alphas:  [ 84.41317289  18.44098513]
# Pattern  0  classification score:  0.99 , separation:  10.588387624228803
# Pattern  1  classification score:  0.99 , separation:  4.8177932173327696
# Computing conceptors, alphas:  [ 76.44709905  38.16982295]
# Pattern  0  classification score:  0.99 , separation:  9.429574594253681
# Pattern  1  classification score:  0.99 , separation:  5.238021671366028
# Computing conceptors, alphas:  [ 57.71665303  62.43724018]
# Pattern  0  classification score:  0.99 , separation:  8.778956841821419
# Pattern  1  classification score:  0.99 , separation:  5.727623754223675
# Computing conceptors, alphas:  [ 23.62909997  54.25459115]
# Pattern  0  classification score:  0.99 , separation:  8.736792391687032
# Pattern  1  classification score:  0.99 , separation:  7.878775958483475
# Computing conceptors, alphas:  [ 77.49529951  99.0823564 ]
# Pattern  0  classification score:  0.99 , separation:  8.1605074475401
# Pattern  1  classification score:  0.99 , separation:  5.314271314384965
# Computing conceptors, alphas:  [ 86.79467614  43.03229151]
# Pattern  0  classification score:  0.99 , separation:  9.282623115320447
# Pattern  1  classification score:  0.99 , separation:  5.09192712087334
# Computing conceptors, alphas:  [ 48.91439585  59.57595283]
# Pattern  0  classification score:  0.99 , separation:  8.81850998315713
# Pattern  1  classification score:  0.99 , separation:  6.012797708146865
# Computing conceptors, alphas:  [ 92.16692762  33.41136475]
# Pattern  0  classification score:  0.99 , separation:  9.618382249229125
# Pattern  1  classification score:  0.99 , separation:  4.964868031263716
# Computing conceptors, alphas:  [ 87.42774807  79.96774855]
# Pattern  0  classification score:  0.99 , separation:  8.481036186393762
# Pattern  1  classification score:  0.99 , separation:  5.145508587779506
# Computing conceptors, alphas:  [ 36.57980729  59.33759945]
# Pattern  0  classification score:  0.99 , separation:  8.770414279794888
# Pattern  1  classification score:  0.99 , separation:  6.618651885012016
# Computing conceptors, alphas:  [ 26.97043916  59.8818039 ]
# Pattern  0  classification score:  0.99 , separation:  8.667752110809458
# Pattern  1  classification score:  0.99 , separation:  7.444955696066969
# Computing conceptors, alphas:  [ 76.90983214  55.73807551]
# Pattern  0  classification score:  0.99 , separation:  8.948371977120303
# Pattern  1  classification score:  0.99 , separation:  5.285849103664151
# Computing conceptors, alphas:  [ 79.75390518  46.41019631]
# Pattern  0  classification score:  0.99 , separation:  9.181780116891344
# Pattern  1  classification score:  0.99 , separation:  5.214021753881818
# Computing conceptors, alphas:  [ 99.21785522  16.92821617]
# Pattern  0  classification score:  0.99 , separation:  10.777995737122293
# Pattern  1  classification score:  0.99 , separation:  4.555434570117887
# Computing conceptors, alphas:  [ 53.44410592  35.59352621]
# Pattern  0  classification score:  0.99 , separation:  9.488528460140108
# Pattern  1  classification score:  0.99 , separation:  5.77615148998079
# Computing conceptors, alphas:  [ 11.72436743  99.27046655]
# Pattern  0  classification score:  0.99 , separation:  7.336047640991953
# Pattern  1  classification score:  0.99 , separation:  11.811216052561402
# Computing conceptors, alphas:  [ 67.37699797  43.46590684]
# Pattern  0  classification score:  0.99 , separation:  9.252601009445675
# Pattern  1  classification score:  0.99 , separation:  5.441911190363285
# Computing conceptors, alphas:  [ 61.94230533  59.35458051]
# Pattern  0  classification score:  0.99 , separation:  8.85106543054628
# Pattern  1  classification score:  0.99 , separation:  5.609345116988164

# %%
#which are the best apertures?
bestConceptor = conceptorNets[2]
import dill as pickle
with open(r"net.pickle", "wb") as output_file:
    pickle.dump(bestConceptor, output_file, protocol=0)
