# %%
import cellbell
# %pylab inline
import csv
import scipy as sp
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
logfiles = ["conceptors__171127_141748/conceptors__171127_141748_0_171127_141748.txt",
"conceptors__171127_141754/conceptors__171127_141754_0_171127_141754.txt",
"conceptors__171127_141800/conceptors__171127_141800_0_171127_141800.txt",
"conceptors__171127_141824/conceptors__171127_141824_0_171127_141824.txt",
"conceptors__171127_141830/conceptors__171127_141830_0_171127_141830.txt",
"conceptors__171127_141835/conceptors__171127_141835_0_171127_141835.txt",
"conceptors__171127_141839/conceptors__171127_141839_0_171127_141839.txt",
"conceptors__171127_141846/conceptors__171127_141846_0_171127_141846.txt",
"conceptors__171127_141854/conceptors__171127_141854_0_171127_141854.txt",
"conceptors__171127_141912/conceptors__171127_141912_0_171127_141912.txt",
"conceptors__171127_141923/conceptors__171127_141923_0_171127_141923.txt",
"conceptors__171127_141931/conceptors__171127_141931_0_171127_141931.txt",
"conceptors__171127_141936/conceptors__171127_141936_0_171127_141936.txt",
"conceptors__171127_141948/conceptors__171127_141948_0_171127_141948.txt",
"conceptors__171127_142005/conceptors__171127_142005_0_171127_142005.txt"
];

videofiles = [
"conceptors_171127_141729_0.avi",
"conceptors_171127_141729_1.avi",
"conceptors_171127_141729_2.avi",
"conceptors_171127_141814_0.avi",
"conceptors_171127_141814_1.avi",
"conceptors_171127_141814_2.avi",
"conceptors_171127_141814_3.avi",
"conceptors_171127_141814_4.avi",
"conceptors_171127_141814_5.avi",
"conceptors_171127_141814_6.avi",
"conceptors_171127_141814_7.avi",
"conceptors_171127_141814_8.avi",
"conceptors_171127_141814_9.avi",
"conceptors_171127_141814_10.avi",
"conceptors_171127_141814_11.avi"
];

# %%
gestureRanges = np.array([[10,50],[10,55],[0,40],[0,30],[0,35], [0,25], [0,32], [0,80],[0,118],[5,105],[0,30],[3,52],[1,50],[0,170],[0,95]])

# %%
dataRoot ='./data/acc_gestures/'
gestures = np.zeros(len(logfiles), dtype=np.object)
def loadGesture(idx):
    started = 0
    gesture = []
    with open(dataRoot + logfiles[idx], 'r') as csvfile:
        creader = csv.reader(csvfile, delimiter='\t', quotechar='\'')
        for row in creader:
            print(row[1])
            if (row[1] == '/videorec/record/start'):
                started = 1
                print("started")
            if started == 1:
                if(row[1] == '/minibee/data'):
                    print(row[8])
                    gesture = np.append(gesture, [float(row[8]), float(row[9]), float(row[10])])
    return 2*(gesture - 0.5)

for i in arange(len(logfiles)):
    gestures[i] = loadGesture(i) 
    gestures[i] = gestures[i].reshape((int(gestures[i].shape[0]/3)),3)

maxScale = np.max([np.max(abs(x)) for x in gestures])
print(maxScale)
gestures = gestures/maxScale

for i in arange(len(gestures)):
    gestures[i] = gestures[i][gestureRanges[i][0]:gestureRanges[i][1]]
# Out:
# /minibee/data
# /videorec/record/start
# started
# /minibee/data
# 0.50445610284805
# /videorec/frame
# /minibee/data
# 0.50445610284805
# /videorec/frame
# /minibee/data
# 0.5050665140152
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.5047003030777
# /videorec/frame
# /minibee/data
# 0.50408983230591
# /videorec/frame
# /minibee/data
# 0.50421196222305
# /videorec/frame
# /minibee/data
# 0.50445610284805
# /videorec/frame
# /minibee/data
# 0.50445610284805
# /videorec/frame
# /minibee/data
# 0.50457817316055
# /videorec/frame
# /minibee/data
# 0.50433403253555
# /videorec/frame
# /minibee/data
# 0.50445610284805
# /videorec/frame
# /minibee/data
# 0.5050665140152
# /videorec/frame
# /minibee/data
# 0.50579905509949
# /videorec/frame
# /minibee/data
# 0.50616532564163
# /videorec/frame
# /minibee/data
# 0.50543278455734
# /videorec/frame
# /minibee/data
# 0.50335735082626
# /videorec/frame
# /minibee/data
# 0.50079357624054
# /videorec/frame
# /minibee/data
# 0.50018310546875
# /videorec/frame
# /minibee/data
# 0.50018310546875
# /videorec/frame
# /minibee/data
# 0.49981686472893
# /videorec/frame
# /minibee/data
# 0.49993896484375
# /videorec/frame
# /minibee/data
# 0.49945062398911
# /videorec/frame
# /minibee/data
# 0.49993896484375
# /videorec/frame
# /minibee/data
# 0.49957269430161
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.50030523538589
# /videorec/frame
# /minibee/data
# 0.50115978717804
# /videorec/frame
# /minibee/data
# 0.50115978717804
# /videorec/frame
# /minibee/data
# 0.50201439857483
# /videorec/frame
# /minibee/data
# 0.50115978717804
# /videorec/frame
# /minibee/data
# 0.50213646888733
# /videorec/frame
# /minibee/data
# 0.50201439857483
# /videorec/frame
# /minibee/data
# 0.50225859880447
# /videorec/frame
# /minibee/data
# 0.50128191709518
# /videorec/frame
# /minibee/data
# 0.50177025794983
# /videorec/frame
# /minibee/data
# 0.50201439857483
# /videorec/frame
# /minibee/data
# 0.50274693965912
# /videorec/frame
# /minibee/data
# 0.50250273942947
# /videorec/frame
# /minibee/data
# 0.50408983230591
# /videorec/frame
# /minibee/data
# 0.50433403253555
# /videorec/frame
# /minibee/data
# 0.5049444437027
# /videorec/frame
# /minibee/data
# 0.50421196222305
# /videorec/frame
# /minibee/data
# 0.5048223733902
# /videorec/frame
# /minibee/data
# 0.50457817316055
# /videorec/frame
# /minibee/data
# 0.50286900997162
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.50225859880447
# /videorec/frame
# /minibee/data
# 0.50103771686554
# /videorec/frame
# /minibee/data
# 0.50128191709518
# /videorec/frame
# /minibee/data
# 0.50213646888733
# /videorec/frame
# /minibee/data
# 0.50274693965912
# /videorec/frame
# /minibee/data
# 0.50323528051376
# /videorec/frame
# /minibee/data
# 0.50299108028412
# /videorec/frame
# /minibee/data
# 0.50323528051376
# /videorec/frame
# /minibee/data
# 0.50311315059662
# /videorec/frame
# /minibee/data
# 0.50323528051376
# /videorec/frame
# /minibee/data
# 0.50323528051376
# /videorec/frame
# /minibee/data
# 0.50311315059662
# /videorec/frame
# /minibee/data
# 0.50311315059662
# /videorec/frame
# /minibee/data
# 0.50323528051376
# /videorec/frame
# /minibee/data
# 0.50335735082626
# /videorec/frame
# /minibee/data
# /videorec/record/start
# started
# /videorec/frame
# /minibee/data
# 0.50250273942947
# /videorec/frame
# /minibee/data
# 0.50213646888733
# /videorec/frame
# /minibee/data
# 0.50250273942947
# /videorec/frame
# /minibee/data
# 0.5047003030777
# /videorec/frame
# /minibee/data
# 0.50604319572449
# /videorec/frame
# /minibee/data
# 0.50836282968521
# /videorec/frame
# /minibee/data
# 0.51007205247879
# /videorec/frame
# /minibee/data
# 0.51263582706451
# /videorec/frame
# /minibee/data
# 0.51422291994095
# /videorec/frame
# /minibee/data
# 0.51568794250488
# /videorec/frame
# /minibee/data
# 0.51776337623596
# /videorec/frame
# /minibee/data
# 0.51788550615311
# /minibee/data
# 0.51764130592346
# /videorec/frame
# /minibee/data
# 0.51654255390167
# /videorec/frame
# /minibee/data
# 0.51654255390167
# /videorec/frame
# /minibee/data
# 0.51519960165024
# /videorec/frame
# /minibee/data
# 0.51275789737701
# /minibee/data
# 0.50982785224915
# /videorec/frame
# /minibee/data
# 0.50885117053986
# /videorec/frame
# /minibee/data
# 0.50799655914307
# /videorec/frame
# /minibee/data
# 0.50579905509949
# /videorec/frame
# /minibee/data
# 0.50384569168091
# /minibee/data
# 0.50128191709518
# /videorec/frame
# /minibee/data
# 0.50006103515625
# /videorec/frame
# /minibee/data
# 0.49969479441643
# /videorec/frame
# /minibee/data
# 0.49810767173767
# /videorec/frame
# /minibee/data
# 0.49859601259232
# /minibee/data
# 0.49627640843391
# /videorec/frame
# /minibee/data
# 0.49566596746445
# /videorec/frame
# /minibee/data
# 0.49529972672462
# /videorec/frame
# /minibee/data
# 0.49688681960106
# /videorec/frame
# /minibee/data
# 0.49920645356178
# /minibee/data
# 0.50164812803268
# /videorec/frame
# /minibee/data
# 0.50836282968521
# /videorec/frame
# /minibee/data
# 0.51287996768951
# /videorec/frame
# /minibee/data
# 0.51617628335953
# /videorec/frame
# /minibee/data
# 0.51654255390167
# /videorec/frame
# /minibee/data
# 0.51703089475632
# /videorec/frame
# /minibee/data
# 0.51788550615311
# /videorec/frame
# /minibee/data
# 0.5188621878624
# /minibee/data
# 0.51849591732025
# /videorec/frame
# /minibee/data
# 0.51507753133774
# /videorec/frame
# /minibee/data
# 0.51483333110809
# /videorec/frame
# /minibee/data
# 0.51043826341629
# /videorec/frame
# /minibee/data
# 0.50787448883057
# /videorec/frame
# /minibee/data
# 0.50579905509949
# /videorec/frame
# /minibee/data
# 0.50311315059662
# /videorec/frame
# /minibee/data
# 0.50030523538589
# /videorec/frame
# /minibee/data
# 0.50006103515625
# /videorec/frame
# /minibee/data
# 0.49884018301964
# /minibee/data
# 0.49945062398911
# /videorec/frame
# /minibee/data
# 0.50006103515625
# /videorec/frame
# /minibee/data
# 0.50018310546875
# /videorec/frame
# /minibee/data
# 0.50079357624054
# /videorec/frame
# /minibee/data
# 0.50152605772018
# /videorec/frame
# /minibee/data
# 0.50128191709518
# /videorec/frame
# /minibee/data
# 0.50115978717804
# /videorec/record/start
# started
# /minibee/data
# 0.50347942113876
# /videorec/frame
# /minibee/data
# 0.50286900997162
# /videorec/frame
# /minibee/data
# 0.50238066911697
# /videorec/frame
# /minibee/data
# 0.50286900997162
# /videorec/frame
# /minibee/data
# 0.50457817316055
# /videorec/frame
# /minibee/data
# 0.50726407766342
# /videorec/frame
# /minibee/data
# 0.51056039333344
# /videorec/frame
# /minibee/data
# 0.5137345790863
# /videorec/frame
# /minibee/data
# 0.51617628335953
# /videorec/frame
# /minibee/data
# 0.51690882444382
# /videorec/frame
# /minibee/data
# 0.51678669452667
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.51727503538132
# /videorec/frame
# /minibee/data
# 0.51947259902954
# /videorec/frame
# /minibee/data
# 0.52179223299026
# /videorec/frame
# /minibee/data
# 0.51996093988419
# /videorec/frame
# /minibee/data
# 0.51861798763275
# /videorec/frame
# /minibee/data
# 0.51971673965454
# /videorec/frame
# /minibee/data
# 0.51935052871704
# /videorec/frame
# /minibee/data
# 0.5189842581749
# /videorec/frame
# /minibee/data
# 0.51800757646561
# /videorec/frame
# /minibee/data
# 0.5188621878624
# /videorec/frame
# /minibee/data
# 0.51605421304703
# /videorec/frame
# /minibee/data
# 0.51727503538132
# /videorec/frame
# /minibee/data
# 0.51593214273453
# /videorec/frame
# /minibee/data
# 0.51007205247879
# /videorec/frame
# /minibee/data
# 0.50604319572449
# /videorec/frame
# /minibee/data
# 0.50335735082626
# /videorec/frame
# /minibee/data
# 0.50286900997162
# /videorec/frame
# /minibee/data
# 0.49871811270714
# /videorec/frame
# /minibee/data
# 0.49493345618248
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.49774143099785
# /videorec/frame
# /minibee/data
# 0.49871811270714
# /videorec/frame
# /minibee/data
# 0.49993896484375
# /minibee/data
# 0.50250273942947
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.50372362136841
# /videorec/frame
# /minibee/data
# 0.50384569168091
# /videorec/frame
# /minibee/data
# 0.50311315059662
# /videorec/frame
# /minibee/data
# 0.50347942113876
# /videorec/frame
# /minibee/data
# 0.50360149145126
# /videorec/frame
# /minibee/data
# 0.50384569168091
# /videorec/frame
# /minibee/data
# 0.50408983230591
# /videorec/frame
# /minibee/data
# 0.50433403253555
# /videorec/frame
# /minibee/data
# 0.50421196222305
# /videorec/frame
# /minibee/data
# 0.50445610284805
# /videorec/frame
# /minibee/data
# 0.50433403253555
# /videorec/frame
# /minibee/data
# 0.50457817316055
# /videorec/frame
# /minibee/data
# 0.50421196222305
# /videorec/record/start
# started
# /minibee/data
# 0.50592112541199
# /videorec/frame
# /minibee/data
# 0.51019412279129
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.51861798763275
# /minibee/data
# 0.52447807788849
# /videorec/frame
# /minibee/data
# 0.53387862443924
# /videorec/frame
# /minibee/data
# 0.53522157669067
# /videorec/frame
# /minibee/data
# 0.51495546102524
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.50616532564163
# /videorec/frame
# /minibee/data
# 0.48821878433228
# /videorec/frame
# /minibee/data
# 0.49249175190926
# /videorec/frame
# /minibee/data
# 0.50177025794983
# /videorec/frame
# /minibee/data
# 0.49798560142517
# /videorec/frame
# /minibee/data
# 0.48870712518692
# /videorec/frame
# /minibee/data
# 0.47564399242401
# /videorec/frame
# /minibee/data
# 0.49981686472893
# /videorec/frame
# /minibee/data
# 0.51251375675201
# /videorec/frame
# /minibee/data
# 0.52606517076492
# /videorec/frame
# /minibee/data
# 0.52850687503815
# /videorec/frame
# /minibee/data
# 0.53180319070816
# /videorec/frame
# /minibee/data
# 0.51800757646561
# /videorec/frame
# /minibee/data
# 0.51226955652237
# /videorec/frame
# /minibee/data
# 0.51739716529846
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.52044928073883
# /minibee/data
# 0.52057135105133
# /videorec/frame
# /minibee/data
# 0.51764130592346
# /videorec/frame
# /minibee/data
# 0.51642048358917
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.51556587219238
# /videorec/frame
# /minibee/data
# 0.51507753133774
# /videorec/frame
# /minibee/data
# 0.51556587219238
# /videorec/frame
# /minibee/data
# 0.51519960165024
# /videorec/frame
# /minibee/data
# 0.51593214273453
# /videorec/frame
# /minibee/data
# 0.51605421304703
# /videorec/frame
# /minibee/data
# 0.51568794250488
# /videorec/frame
# /minibee/data
# 0.51556587219238
# /videorec/frame
# /minibee/data
# 0.51544380187988
# /videorec/frame
# /minibee/data
# 0.51568794250488
# /videorec/frame
# /minibee/data
# 0.51593214273453
# /videorec/frame
# /minibee/data
# 0.51568794250488
# /videorec/frame
# /minibee/data
# 0.51568794250488
# /videorec/frame
# /minibee/data
# 0.51568794250488
# /videorec/frame
# /videorec/record/start
# started
# /minibee/data
# 0.50347942113876
# /videorec/frame
# /minibee/data
# 0.49322426319122
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.48223659396172
# /videorec/frame
# /minibee/data
# 0.4973751604557
# /videorec/frame
# /minibee/data
# 0.5138566493988
# /videorec/frame
# /minibee/data
# 0.53070443868637
# /videorec/frame
# /minibee/data
# 0.53290194272995
# /videorec/frame
# /minibee/data
# 0.51983886957169
# /videorec/frame
# /minibee/data
# 0.4973751604557
# /videorec/frame
# /minibee/data
# 0.48028323054314
# /videorec/frame
# /minibee/data
# 0.47686484456062
# /videorec/frame
# /minibee/data
# 0.48357954621315
# /videorec/frame
# /minibee/data
# 0.49554389715195
# /videorec/frame
# /minibee/data
# 0.50836282968521
# /videorec/frame
# /minibee/data
# 0.51422291994095
# /videorec/frame
# /minibee/data
# 0.5093395113945
# /videorec/frame
# /minibee/data
# 0.51983886957169
# /videorec/frame
# /minibee/data
# 0.51788550615311
# /videorec/frame
# /minibee/data
# 0.49749726057053
# /videorec/frame
# /minibee/data
# 0.4885850250721
# /videorec/frame
# /minibee/data
# 0.47735318541527
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.49005004763603
# /minibee/data
# 0.49005004763603
# /videorec/frame
# /minibee/data
# 0.50457817316055
# /videorec/frame
# /minibee/data
# 0.51532167196274
# /videorec/frame
# /minibee/data
# 0.52142596244812
# /videorec/frame
# /minibee/data
# 0.51629835367203
# /videorec/frame
# /minibee/data
# 0.49566596746445
# /videorec/frame
# /minibee/data
# 0.50604319572449
# /videorec/frame
# /minibee/data
# 0.50714200735092
# /videorec/frame
# /minibee/data
# 0.50763034820557
# /videorec/frame
# /minibee/data
# 0.50592112541199
# /videorec/frame
# /minibee/data
# 0.50689780712128
# /videorec/frame
# /minibee/data
# 0.50628739595413
# /videorec/frame
# /minibee/data
# 0.50738614797592
# /videorec/frame
# /minibee/data
# 0.50824075937271
# /videorec/frame
# /minibee/data
# 0.50824075937271
# /videorec/frame
# /videorec/record/start
# started
# /minibee/data
# 0.51825171709061
# /videorec/frame
# /minibee/data
# 0.50653153657913
# /videorec/frame
# /minibee/data
# 0.49945062398911
# /videorec/frame
# /minibee/data
# 0.49713099002838
# /videorec/frame
# /minibee/data
# 0.48882919549942
# /videorec/frame
# /minibee/data
# 0.4766206741333
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.47845196723938
# /minibee/data
# 0.4885850250721
# /videorec/frame
# /minibee/data
# 0.50079357624054
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.51287996768951
# /minibee/data
# 0.51935052871704
# /videorec/frame
# /minibee/data
# 0.50750821828842
# /videorec/frame
# /minibee/data
# 0.49957269430161
# /videorec/frame
# /minibee/data
# 0.50738614797592
# /videorec/frame
# /minibee/data
# 0.49468928575516
# /videorec/frame
# /minibee/data
# 0.4885850250721
# /videorec/frame
# /minibee/data
# 0.47259187698364
# /videorec/frame
# /minibee/data
# 0.47417896986008
# /videorec/frame
# /minibee/data
# 0.49334636330605
# /videorec/frame
# /minibee/data
# 0.50592112541199
# /minibee/data
# 0.51239162683487
# /videorec/frame
# /minibee/data
# 0.51519960165024
# /videorec/frame
# /minibee/data
# 0.50811868906021
# /videorec/frame
# /minibee/data
# 0.50665366649628
# /minibee/data
# 0.50665366649628
# /videorec/frame
# /minibee/data
# 0.5134904384613
# /videorec/frame
# /minibee/data
# 0.51080453395844
# /videorec/frame
# /minibee/data
# 0.50848489999771
# /videorec/frame
# /minibee/data
# 0.50799655914307
# /videorec/frame
# /minibee/data
# 0.50604319572449
# /videorec/frame
# /minibee/data
# 0.50714200735092
# /videorec/frame
# /minibee/data
# 0.50787448883057
# /minibee/data
# 0.5090953707695
# /videorec/record/start
# started
# /minibee/data
# 0.50665366649628
# /videorec/frame
# /minibee/data
# 0.51153707504272
# /videorec/frame
# /minibee/data
# 0.51825171709061
# /videorec/frame
# /minibee/data
# 0.51837384700775
# /videorec/frame
# /minibee/data
# 0.50689780712128
# /videorec/frame
# /minibee/data
# 0.49554389715195
# /videorec/frame
# /minibee/data
# 0.48724210262299
# /videorec/frame
# /minibee/data
# 0.48724210262299
# /videorec/frame
# /minibee/data
# 0.49749726057053
# /videorec/frame
# /minibee/data
# 0.52679771184921
# /videorec/frame
# /minibee/data
# 0.52606517076492
# /videorec/frame
# /minibee/data
# 0.51300209760666
# /videorec/frame
# /minibee/data
# 0.48187035322189
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.46197044849396
# /videorec/frame
# /minibee/data
# 0.48125991225243
# /videorec/frame
# /minibee/data
# 0.50262480974197
# /videorec/frame
# /minibee/data
# 0.47845196723938
# /videorec/frame
# /minibee/data
# 0.48919546604156
# /videorec/frame
# /minibee/data
# 0.50006103515625
# /videorec/frame
# /minibee/data
# 0.51495546102524
# /videorec/frame
# /minibee/data
# 0.5233793258667
# /minibee/data
# 0.53131484985352
# /videorec/frame
# /minibee/data
# 0.50274693965912
# /videorec/frame
# /minibee/data
# 0.51971673965454
# /videorec/frame
# /minibee/data
# 0.5090953707695
# /videorec/frame
# /minibee/data
# 0.50103771686554
# /videorec/frame
# /minibee/data
# 0.50274693965912
# /videorec/frame
# /minibee/data
# 0.48797461390495
# /videorec/frame
# /minibee/data
# 0.50860702991486
# /videorec/frame
# /minibee/data
# 0.52691978216171
# /videorec/frame
# /minibee/data
# 0.52545475959778
# /videorec/frame
# /minibee/data
# 0.52289098501205
# /minibee/data
# 0.5191063284874
# /videorec/frame
# /minibee/data
# 0.5235013961792
# /videorec/frame
# /minibee/data
# 0.52460014820099
# /videorec/frame
# /minibee/data
# 0.52203637361526
# /videorec/frame
# /minibee/data
# 0.5235013961792
# /videorec/frame
# /videorec/record/start
# started
# /videorec/frame
# /minibee/data
# 0.5136125087738
# /videorec/frame
# /minibee/data
# 0.51593214273453
# /videorec/frame
# /minibee/data
# 0.51434499025345
# /videorec/frame
# /minibee/data
# 0.5093395113945
# /videorec/frame
# /minibee/data
# 0.51605421304703
# /videorec/frame
# /minibee/data
# 0.51727503538132
# /videorec/frame
# /minibee/data
# 0.50665366649628
# /videorec/frame
# /minibee/data
# 0.52069342136383
# /videorec/frame
# /minibee/data
# 0.51007205247879
# /videorec/frame
# /minibee/data
# 0.50360149145126
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.51837384700775
# /minibee/data
# 0.50799655914307
# /videorec/frame
# /minibee/data
# 0.50555485486984
# /videorec/frame
# /minibee/data
# 0.52044928073883
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.51056039333344
# /videorec/frame
# /minibee/data
# 0.5090953707695
# /videorec/frame
# /minibee/data
# 0.51275789737701
# /videorec/frame
# /minibee/data
# 0.50018310546875
# /videorec/frame
# /minibee/data
# 0.52484434843063
# /videorec/frame
# /minibee/data
# 0.50128191709518
# /videorec/frame
# /minibee/data
# 0.52154803276062
# /videorec/frame
# /minibee/data
# 0.51495546102524
# /videorec/frame
# /minibee/data
# 0.51165914535522
# /videorec/frame
# /minibee/data
# 0.51556587219238
# /videorec/frame
# /minibee/data
# 0.50579905509949
# /videorec/frame
# /minibee/data
# 0.52105969190598
# /videorec/frame
# /minibee/data
# 0.50653153657913
# /videorec/frame
# /minibee/data
# 0.51532167196274
# /videorec/frame
# /minibee/data
# 0.51214748620987
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.50531071424484
# /videorec/frame
# /minibee/data
# 0.51336830854416
# /videorec/frame
# /minibee/data
# 0.51031619310379
# /videorec/frame
# /minibee/data
# 0.50763034820557
# /videorec/frame
# /minibee/data
# 0.51336830854416
# /videorec/frame
# /minibee/data
# 0.52826273441315
# /videorec/frame
# /minibee/data
# 0.51019412279129
# /videorec/frame
# /minibee/data
# 0.51544380187988
# /videorec/frame
# /minibee/data
# 0.52618730068207
# /videorec/frame
# /minibee/data
# 0.51165914535522
# /videorec/frame
# /minibee/data
# 0.50811868906021
# /videorec/frame
# /minibee/data
# 0.52215844392776
# /videorec/frame
# /minibee/data
# 0.50433403253555
# /videorec/frame
# /minibee/data
# 0.5050665140152
# /videorec/frame
# /minibee/data
# 0.52533268928528
# /videorec/frame
# /minibee/data
# 0.5047003030777
# /videorec/frame
# /minibee/data
# 0.50396776199341
# /videorec/frame
# /minibee/data
# 0.5233793258667
# /videorec/frame
# /minibee/data
# 0.49639847874641
# /videorec/frame
# /minibee/data
# 0.50616532564163
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.52289098501205
# /videorec/frame
# /minibee/data
# 0.50177025794983
# /videorec/frame
# /minibee/data
# 0.50140398740768
# /videorec/frame
# /minibee/data
# 0.52093762159348
# /minibee/data
# 0.49774143099785
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.50994992256165
# /videorec/frame
# /minibee/data
# 0.5233793258667
# /videorec/frame
# /minibee/data
# 0.5280185341835
# /videorec/frame
# /minibee/data
# 0.50775241851807
# /videorec/frame
# /minibee/data
# 0.51056039333344
# /videorec/frame
# /minibee/data
# 0.52887314558029
# /videorec/frame
# /minibee/data
# 0.51727503538132
# /videorec/frame
# /minibee/data
# 0.49835184216499
# /videorec/frame
# /minibee/data
# 0.51837384700775
# /videorec/frame
# /minibee/data
# 0.49334636330605
# /videorec/frame
# /minibee/data
# 0.50714200735092
# /videorec/frame
# /minibee/data
# 0.51935052871704
# /videorec/frame
# /minibee/data
# 0.5047003030777
# /videorec/frame
# /minibee/data
# 0.50152605772018
# /videorec/frame
# /minibee/data
# 0.52228057384491
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.5233793258667
# /videorec/frame
# /minibee/data
# 0.50958371162415
# /videorec/frame
# /minibee/data
# 0.50628739595413
# /videorec/frame
# /minibee/data
# 0.51739716529846
# /videorec/frame
# /minibee/data
# 0.49529972672462
# /videorec/frame
# /minibee/data
# 0.509217441082
# /videorec/frame
# /minibee/data
# 0.51410084962845
# /videorec/frame
# /minibee/data
# 0.48785251379013
# /videorec/frame
# /minibee/data
# 0.50567698478699
# /videorec/frame
# /minibee/data
# 0.5188621878624
# /videorec/frame
# /minibee/data
# 0.51519960165024
# /videorec/frame
# /minibee/data
# 0.509461581707
# /videorec/frame
# /minibee/data
# 0.51959466934204
# /videorec/frame
# /minibee/data
# 0.51117080450058
# /videorec/frame
# /minibee/data
# 0.50848489999771
# /videorec/frame
# /minibee/data
# 0.51532167196274
# /videorec/frame
# /minibee/data
# 0.51874005794525
# /videorec/frame
# /minibee/data
# 0.50994992256165
# /videorec/frame
# /minibee/data
# 0.51178121566772
# /videorec/frame
# /minibee/data
# 0.51825171709061
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.51104873418808
# /videorec/frame
# /minibee/data
# 0.51263582706451
# /videorec/record/start
# started
# /minibee/data
# 0.50311315059662
# /videorec/frame
# /minibee/data
# 0.50335735082626
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.50323528051376
# /videorec/frame
# /minibee/data
# 0.50299108028412
# /videorec/frame
# /minibee/data
# 0.50201439857483
# /minibee/data
# 0.50335735082626
# /videorec/frame
# /minibee/data
# 0.50238066911697
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.50396776199341
# /videorec/frame
# /minibee/data
# 0.50396776199341
# /videorec/frame
# /minibee/data
# 0.50433403253555
# /videorec/frame
# /minibee/data
# 0.5047003030777
# /videorec/frame
# /minibee/data
# 0.50433403253555
# /videorec/frame
# /minibee/data
# 0.50372362136841
# /videorec/frame
# /minibee/data
# 0.5049444437027
# /videorec/frame
# /minibee/data
# 0.50408983230591
# /videorec/frame
# /minibee/data
# 0.50408983230591
# /videorec/frame
# /minibee/data
# 0.50445610284805
# /videorec/frame
# /minibee/data
# 0.50408983230591
# /videorec/frame
# /minibee/data
# 0.50543278455734
# /videorec/frame
# /minibee/data
# 0.50384569168091
# /videorec/frame
# /minibee/data
# 0.50384569168091
# /videorec/frame
# /minibee/data
# 0.50433403253555
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.5049444437027
# /minibee/data
# 0.50421196222305
# /videorec/frame
# /minibee/data
# 0.5049444437027
# /videorec/frame
# /minibee/data
# 0.50421196222305
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.50445610284805
# /videorec/frame
# /minibee/data
# 0.5049444437027
# /videorec/frame
# /minibee/data
# 0.50433403253555
# /videorec/frame
# /minibee/data
# 0.5047003030777
# /videorec/frame
# /minibee/data
# 0.50384569168091
# /videorec/frame
# /minibee/data
# 0.5048223733902
# /videorec/frame
# /minibee/data
# 0.5050665140152
# /videorec/frame
# /minibee/data
# 0.50433403253555
# /videorec/frame
# /minibee/data
# 0.5047003030777
# /videorec/frame
# /minibee/data
# 0.50445610284805
# /videorec/frame
# /minibee/data
# 0.50653153657913
# /videorec/frame
# /minibee/data
# 0.50372362136841
# /videorec/frame
# /minibee/data
# 0.5047003030777
# /videorec/frame
# /minibee/data
# 0.50616532564163
# /videorec/frame
# /minibee/data
# 0.50433403253555
# /videorec/frame
# /minibee/data
# 0.50433403253555
# /videorec/frame
# /minibee/data
# 0.5050665140152
# /videorec/frame
# /minibee/data
# 0.50604319572449
# /videorec/frame
# /minibee/data
# 0.50347942113876
# /videorec/frame
# /minibee/data
# 0.50640946626663
# /videorec/frame
# /minibee/data
# 0.5050665140152
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.50421196222305
# /videorec/frame
# /minibee/data
# 0.50433403253555
# /videorec/frame
# /minibee/data
# 0.50543278455734
# /videorec/frame
# /minibee/data
# 0.50628739595413
# /videorec/frame
# /minibee/data
# 0.50457817316055
# /videorec/frame
# /minibee/data
# 0.5048223733902
# /videorec/frame
# /minibee/data
# 0.50579905509949
# /videorec/frame
# /minibee/data
# 0.50396776199341
# /videorec/frame
# /minibee/data
# 0.50579905509949
# /videorec/frame
# /minibee/data
# 0.5048223733902
# /videorec/frame
# /minibee/data
# 0.5050665140152
# /videorec/frame
# /minibee/data
# 0.5050665140152
# /videorec/frame
# /minibee/data
# 0.5047003030777
# /videorec/frame
# /minibee/data
# 0.50677573680878
# /videorec/frame
# /minibee/data
# 0.5047003030777
# /videorec/frame
# /minibee/data
# 0.50640946626663
# /videorec/frame
# /minibee/data
# 0.50592112541199
# /videorec/frame
# /minibee/data
# 0.50531071424484
# /videorec/frame
# /minibee/data
# 0.50592112541199
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.5049444437027
# /videorec/frame
# /minibee/data
# 0.50592112541199
# /videorec/frame
# /minibee/data
# 0.50616532564163
# /videorec/frame
# /minibee/data
# 0.50408983230591
# /videorec/frame
# /minibee/data
# 0.50616532564163
# /videorec/frame
# /minibee/data
# 0.50433403253555
# /videorec/frame
# /minibee/data
# 0.50567698478699
# /videorec/frame
# /minibee/data
# 0.50396776199341
# /videorec/frame
# /minibee/data
# 0.50665366649628
# /videorec/frame
# /minibee/data
# 0.5049444437027
# /videorec/frame
# /minibee/data
# 0.50579905509949
# /videorec/frame
# /minibee/data
# 0.50616532564163
# /videorec/frame
# /minibee/data
# 0.50604319572449
# /videorec/frame
# /minibee/data
# 0.50726407766342
# /videorec/frame
# /minibee/data
# 0.50518864393234
# /videorec/frame
# /minibee/data
# 0.50726407766342
# /videorec/frame
# /minibee/data
# 0.50323528051376
# /videorec/frame
# /minibee/data
# 0.50787448883057
# /videorec/frame
# /minibee/data
# 0.50579905509949
# /videorec/frame
# /minibee/data
# 0.50714200735092
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.50653153657913
# /videorec/frame
# /minibee/data
# 0.50653153657913
# /videorec/frame
# /minibee/data
# 0.50701987743378
# /videorec/frame
# /minibee/data
# 0.50677573680878
# /videorec/frame
# /minibee/data
# 0.50616532564163
# /videorec/frame
# /minibee/data
# 0.50689780712128
# /videorec/frame
# /minibee/data
# 0.50665366649628
# /videorec/frame
# /minibee/data
# 0.50457817316055
# /videorec/frame
# /minibee/data
# 0.50811868906021
# /videorec/frame
# /minibee/data
# 0.50384569168091
# /videorec/frame
# /minibee/data
# 0.50860702991486
# /videorec/frame
# /minibee/data
# 0.50372362136841
# /videorec/frame
# /minibee/data
# 0.50701987743378
# /videorec/frame
# /minibee/data
# 0.50567698478699
# /videorec/frame
# /minibee/data
# 0.50848489999771
# /videorec/frame
# /minibee/data
# 0.50323528051376
# /videorec/frame
# /minibee/data
# 0.50665366649628
# /videorec/frame
# /minibee/data
# 0.50653153657913
# /videorec/frame
# /minibee/data
# 0.50445610284805
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.50824075937271
# /videorec/frame
# /minibee/data
# 0.5049444437027
# /videorec/frame
# /minibee/data
# 0.50811868906021
# /videorec/frame
# /minibee/data
# 0.50384569168091
# /videorec/frame
# /minibee/data
# 0.50885117053986
# /videorec/frame
# /minibee/data
# 0.50396776199341
# /videorec/frame
# /minibee/data
# 0.50848489999771
# /videorec/frame
# /minibee/data
# 0.50616532564163
# /videorec/frame
# /minibee/data
# 0.50677573680878
# /videorec/frame
# /minibee/data
# 0.50531071424484
# /videorec/frame
# /minibee/data
# 0.50579905509949
# /videorec/frame
# /minibee/data
# 0.50738614797592
# /videorec/frame
# /minibee/data
# 0.50396776199341
# /videorec/frame
# /minibee/data
# 0.50701987743378
# /videorec/frame
# /minibee/data
# 0.50628739595413
# /videorec/frame
# /minibee/data
# 0.50714200735092
# /videorec/record/start
# started
# /minibee/data
# 0.50750821828842
# /videorec/frame
# /minibee/data
# 0.50738614797592
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.50750821828842
# /videorec/frame
# /minibee/data
# 0.50763034820557
# /videorec/frame
# /minibee/data
# 0.50750821828842
# /minibee/data
# 0.50726407766342
# /videorec/frame
# /minibee/data
# 0.50738614797592
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.50726407766342
# /videorec/frame
# /minibee/data
# 0.50640946626663
# /videorec/frame
# /minibee/data
# 0.50592112541199
# /videorec/frame
# /minibee/data
# 0.50579905509949
# /videorec/frame
# /minibee/data
# 0.50677573680878
# /videorec/frame
# /minibee/data
# 0.50958371162415
# /videorec/frame
# /minibee/data
# 0.51104873418808
# /videorec/frame
# /minibee/data
# 0.51214748620987
# /videorec/frame
# /minibee/data
# 0.51605421304703
# /videorec/frame
# /minibee/data
# 0.51422291994095
# /videorec/frame
# /minibee/data
# 0.51825171709061
# /videorec/frame
# /minibee/data
# 0.51703089475632
# /videorec/frame
# /minibee/data
# 0.51812964677811
# /videorec/frame
# /minibee/data
# 0.51983886957169
# /videorec/frame
# /minibee/data
# 0.52203637361526
# /videorec/frame
# /minibee/data
# 0.52289098501205
# /videorec/frame
# /minibee/data
# 0.52435600757599
# /videorec/frame
# /minibee/data
# 0.5236234664917
# /videorec/frame
# /minibee/data
# 0.52472227811813
# /videorec/frame
# /minibee/data
# 0.52569895982742
# /videorec/frame
# /minibee/data
# 0.52643144130707
# /videorec/frame
# /minibee/data
# 0.52716398239136
# /videorec/frame
# /minibee/data
# 0.52753019332886
# /videorec/frame
# /minibee/data
# 0.527896463871
# /minibee/data
# 0.5277743935585
# /videorec/frame
# /minibee/data
# 0.52606517076492
# /videorec/frame
# /minibee/data
# 0.52435600757599
# /videorec/frame
# /minibee/data
# 0.5236234664917
# /minibee/data
# 0.52167010307312
# /videorec/frame
# /minibee/data
# 0.5189842581749
# /videorec/frame
# /minibee/data
# 0.51654255390167
# /videorec/frame
# /minibee/data
# 0.51495546102524
# /minibee/data
# 0.51507753133774
# /videorec/frame
# /minibee/data
# 0.51019412279129
# /minibee/data
# 0.50738614797592
# /videorec/frame
# /minibee/data
# 0.50408983230591
# /videorec/frame
# /minibee/data
# 0.50421196222305
# /videorec/frame
# /minibee/data
# 0.50677573680878
# /minibee/data
# 0.50677573680878
# /videorec/frame
# /minibee/data
# 0.50299108028412
# /videorec/frame
# /minibee/data
# 0.50518864393234
# /minibee/data
# 0.50567698478699
# /videorec/frame
# /minibee/data
# 0.5049444437027
# /videorec/frame
# /minibee/data
# 0.50433403253555
# /videorec/frame
# /minibee/data
# 0.50457817316055
# /videorec/frame
# /minibee/data
# 0.5050665140152
# /minibee/data
# 0.50531071424484
# /videorec/frame
# /minibee/data
# 0.5047003030777
# /videorec/frame
# /minibee/data
# 0.50457817316055
# /videorec/frame
# /minibee/data
# 0.50457817316055
# /videorec/frame
# /minibee/data
# 0.5047003030777
# /videorec/frame
# /minibee/data
# 0.50457817316055
# /videorec/frame
# /minibee/data
# 0.5047003030777
# /videorec/frame
# /minibee/data
# 0.5047003030777
# /videorec/frame
# /minibee/data
# 0.50518864393234
# /videorec/frame
# /minibee/data
# 0.5050665140152
# /videorec/frame
# /minibee/data
# 0.50457817316055
# /videorec/frame
# /minibee/data
# 0.50457817316055
# /videorec/frame
# /minibee/data
# 0.5047003030777
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.5047003030777
# /videorec/frame
# /minibee/data
# 0.50457817316055
# /videorec/frame
# /minibee/data
# 0.5047003030777
# /videorec/frame
# /minibee/data
# 0.5049444437027
# /videorec/frame
# /minibee/data
# 0.50604319572449
# /videorec/frame
# /minibee/data
# 0.5050665140152
# /videorec/frame
# /minibee/data
# 0.50616532564163
# /videorec/frame
# /minibee/data
# 0.50799655914307
# /videorec/frame
# /minibee/data
# 0.5134904384613
# /videorec/frame
# /minibee/data
# 0.51434499025345
# /videorec/frame
# /minibee/data
# 0.51214748620987
# /videorec/frame
# /minibee/data
# 0.5138566493988
# /videorec/frame
# /minibee/data
# 0.51495546102524
# /videorec/frame
# /minibee/data
# 0.5138566493988
# /videorec/frame
# /minibee/data
# 0.51642048358917
# /videorec/frame
# /minibee/data
# 0.51715296506882
# /videorec/frame
# /minibee/data
# 0.52057135105133
# /videorec/frame
# /minibee/data
# 0.52240264415741
# /videorec/frame
# /minibee/data
# 0.52435600757599
# /videorec/frame
# /minibee/data
# 0.52630937099457
# /videorec/frame
# /minibee/data
# 0.52472227811813
# /videorec/frame
# /minibee/data
# 0.52411180734634
# /videorec/frame
# /minibee/data
# 0.52276891469955
# /videorec/frame
# /minibee/data
# 0.52044928073883
# /minibee/data
# 0.51849591732025
# /videorec/frame
# /minibee/data
# 0.51617628335953
# /videorec/frame
# /minibee/data
# 0.51068246364594
# /videorec/frame
# /minibee/data
# 0.51068246364594
# /minibee/data
# 0.50872910022736
# /videorec/frame
# /minibee/data
# 0.50738614797592
# /videorec/frame
# /minibee/data
# 0.50433403253555
# /minibee/data
# 0.50579905509949
# /videorec/frame
# /minibee/data
# 0.5047003030777
# /videorec/frame
# /minibee/data
# 0.50518864393234
# /minibee/data
# 0.50457817316055
# /videorec/frame
# /minibee/data
# 0.5047003030777
# /videorec/frame
# /minibee/data
# 0.50396776199341
# /minibee/data
# 0.50286900997162
# /videorec/frame
# /minibee/data
# 0.50299108028412
# /videorec/frame
# /minibee/data
# 0.50286900997162
# /videorec/frame
# /minibee/data
# 0.50323528051376
# /videorec/frame
# /minibee/data
# 0.50311315059662
# /videorec/frame
# /minibee/data
# 0.50274693965912
# /videorec/frame
# /minibee/data
# 0.50311315059662
# /minibee/data
# 0.50299108028412
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.50360149145126
# /videorec/record/start
# started
# /minibee/data
# 0.50543278455734
# /videorec/frame
# /minibee/data
# 0.50238066911697
# /videorec/frame
# /minibee/data
# 0.50250273942947
# /videorec/frame
# /minibee/data
# 0.50274693965912
# /videorec/frame
# /minibee/data
# 0.50103771686554
# /videorec/frame
# /minibee/data
# 0.50286900997162
# /videorec/frame
# /minibee/data
# 0.50543278455734
# /videorec/frame
# /minibee/data
# 0.50848489999771
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.51031619310379
# /videorec/frame
# /minibee/data
# 0.51226955652237
# /videorec/frame
# /minibee/data
# 0.51410084962845
# /videorec/frame
# /minibee/data
# 0.51556587219238
# /videorec/frame
# /minibee/data
# 0.51629835367203
# /videorec/frame
# /minibee/data
# 0.51666462421417
# /videorec/frame
# /minibee/data
# 0.51544380187988
# /videorec/frame
# /minibee/data
# 0.51397877931595
# /videorec/frame
# /minibee/data
# 0.51251375675201
# /videorec/frame
# /minibee/data
# 0.51312416791916
# /videorec/frame
# /minibee/data
# 0.51275789737701
# /videorec/frame
# /minibee/data
# 0.51068246364594
# /videorec/frame
# /minibee/data
# 0.5093395113945
# /videorec/frame
# /minibee/data
# 0.50885117053986
# /videorec/frame
# /minibee/data
# 0.50836282968521
# /videorec/frame
# /minibee/data
# 0.50653153657913
# /videorec/frame
# /minibee/data
# 0.50531071424484
# /videorec/frame
# /minibee/data
# 0.50677573680878
# /videorec/frame
# /minibee/data
# 0.50677573680878
# /videorec/frame
# /minibee/data
# 0.50750821828842
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.50799655914307
# /videorec/frame
# /minibee/data
# 0.50860702991486
# /videorec/frame
# /minibee/data
# 0.50897324085236
# /videorec/record/start
# started
# /minibee/data
# 0.50860702991486
# /videorec/frame
# /minibee/data
# 0.50653153657913
# /videorec/frame
# /minibee/data
# 0.50054937601089
# /videorec/frame
# /minibee/data
# 0.50054937601089
# /videorec/frame
# /minibee/data
# 0.50592112541199
# /videorec/frame
# /minibee/data
# 0.51397877931595
# /videorec/frame
# /minibee/data
# 0.52020508050919
# /videorec/frame
# /minibee/data
# 0.52215844392776
# /videorec/frame
# /minibee/data
# 0.52228057384491
# /videorec/frame
# /minibee/data
# 0.51178121566772
# /videorec/frame
# /minibee/data
# 0.49224758148193
# /videorec/frame
# /minibee/data
# 0.48223659396172
# /videorec/frame
# /minibee/data
# 0.48931753635406
# /videorec/frame
# /minibee/data
# 0.490782558918
# /videorec/frame
# /minibee/data
# 0.49407887458801
# /videorec/frame
# /minibee/data
# 0.50177025794983
# /videorec/frame
# /minibee/data
# 0.50811868906021
# /videorec/frame
# /minibee/data
# 0.51544380187988
# /minibee/data
# 0.51544380187988
# /minibee/data
# 0.52020508050919
# /videorec/frame
# /minibee/data
# 0.52142596244812
# /videorec/frame
# /minibee/data
# 0.51837384700775
# /videorec/frame
# /minibee/data
# 0.50323528051376
# /videorec/frame
# /minibee/data
# 0.49334636330605
# /videorec/frame
# /minibee/data
# 0.48431205749512
# /videorec/frame
# /minibee/data
# 0.48248076438904
# /videorec/frame
# /minibee/data
# 0.48614332079887
# /videorec/frame
# /minibee/data
# 0.49346843361855
# /minibee/data
# 0.49932852387428
# /videorec/frame
# /minibee/data
# 0.50775241851807
# /videorec/frame
# /minibee/data
# 0.51629835367203
# /videorec/frame
# /minibee/data
# 0.52020508050919
# /videorec/frame
# /minibee/data
# 0.52203637361526
# /minibee/data
# 0.52203637361526
# /videorec/frame
# /minibee/data
# 0.51825171709061
# /videorec/frame
# /minibee/data
# 0.50628739595413
# /videorec/frame
# /minibee/data
# 0.49261385202408
# /videorec/frame
# /minibee/data
# 0.48382371664047
# /videorec/frame
# /minibee/data
# 0.47967281937599
# /videorec/frame
# /minibee/data
# 0.48589915037155
# /minibee/data
# 0.49261385202408
# /videorec/frame
# /minibee/data
# 0.50030523538589
# /videorec/frame
# /minibee/data
# 0.50701987743378
# /videorec/frame
# /minibee/data
# 0.51532167196274
# /videorec/frame
# /minibee/data
# 0.52020508050919
# /videorec/frame
# /minibee/data
# 0.5235013961792
# /videorec/frame
# /minibee/data
# 0.51947259902954
# /videorec/frame
# /minibee/data
# 0.51104873418808
# /videorec/frame
# /minibee/data
# 0.50054937601089
# /videorec/frame
# /minibee/data
# 0.49468928575516
# /minibee/data
# 0.4929800927639
# /videorec/frame
# /minibee/data
# 0.49468928575516
# /videorec/frame
# /minibee/data
# 0.49835184216499
# /videorec/frame
# /minibee/data
# 0.50018310546875
# /videorec/frame
# /videorec/record/start
# started
# /minibee/data
# 0.50372362136841
# /videorec/frame
# /minibee/data
# 0.50018310546875
# /videorec/frame
# /minibee/data
# 0.49175924062729
# /videorec/frame
# /minibee/data
# 0.48602125048637
# /videorec/frame
# /minibee/data
# 0.48174825310707
# /videorec/frame
# /minibee/data
# 0.50164812803268
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.50811868906021
# /videorec/frame
# /minibee/data
# 0.52142596244812
# /videorec/frame
# /minibee/data
# 0.52679771184921
# /videorec/frame
# /minibee/data
# 0.52240264415741
# /videorec/frame
# /minibee/data
# 0.52264678478241
# /minibee/data
# 0.51874005794525
# /videorec/frame
# /minibee/data
# 0.52276891469955
# /videorec/frame
# /minibee/data
# 0.52655351161957
# /videorec/frame
# /minibee/data
# 0.52252471446991
# /videorec/frame
# /minibee/data
# 0.50982785224915
# /videorec/frame
# /minibee/data
# 0.49822977185249
# /videorec/frame
# /minibee/data
# 0.49603223800659
# /minibee/data
# 0.4973751604557
# /videorec/frame
# /minibee/data
# 0.49884018301964
# /videorec/frame
# /minibee/data
# 0.49908435344696
# /videorec/frame
# /minibee/data
# 0.49639847874641
# /minibee/data
# 0.49652057886124
# /videorec/frame
# /minibee/data
# 0.49676474928856
# /videorec/frame
# /minibee/data
# 0.48956170678139
# /videorec/frame
# /minibee/data
# 0.50628739595413
# /videorec/frame
# /minibee/data
# 0.50433403253555
# /videorec/frame
# /minibee/data
# 0.51874005794525
# /videorec/frame
# /minibee/data
# 0.52899521589279
# /videorec/frame
# /minibee/data
# 0.52447807788849
# /videorec/frame
# /minibee/data
# 0.52032721042633
# /videorec/frame
# /minibee/data
# 0.51983886957169
# /videorec/frame
# /minibee/data
# 0.52496641874313
# /videorec/frame
# /minibee/data
# 0.52691978216171
# /videorec/frame
# /minibee/data
# 0.52460014820099
# /videorec/frame
# /minibee/data
# 0.52276891469955
# /videorec/frame
# /minibee/data
# 0.51764130592346
# /minibee/data
# 0.51458919048309
# /videorec/frame
# /minibee/data
# 0.50799655914307
# /videorec/frame
# /minibee/data
# 0.49908435344696
# /videorec/frame
# /minibee/data
# 0.49566596746445
# /minibee/data
# 0.49432304501534
# /videorec/frame
# /minibee/data
# 0.4950555562973
# /videorec/frame
# /minibee/data
# 0.4972530901432
# /minibee/data
# 0.49786350131035
# /videorec/frame
# /minibee/data
# 0.49786350131035
# /videorec/frame
# /minibee/data
# 0.49896228313446
# /minibee/data
# 0.49884018301964
# /videorec/frame
# /minibee/data
# 0.49957269430161
# /videorec/frame
# /minibee/data
# 0.49957269430161
# /videorec/frame
# /minibee/data
# 0.49957269430161
# /videorec/frame
# /minibee/data
# 0.49969479441643
# /videorec/record/start
# started
# /minibee/data
# 0.5090953707695
# /videorec/frame
# /minibee/data
# 0.50885117053986
# /videorec/frame
# /minibee/data
# 0.5090953707695
# /videorec/frame
# /minibee/data
# 0.509217441082
# /videorec/frame
# /minibee/data
# 0.50848489999771
# /videorec/frame
# /minibee/data
# 0.50897324085236
# /videorec/frame
# /minibee/data
# 0.51129287481308
# /videorec/frame
# /minibee/data
# 0.509217441082
# /videorec/frame
# /minibee/data
# 0.50885117053986
# /videorec/frame
# /minibee/data
# 0.50824075937271
# /videorec/frame
# /minibee/data
# 0.50982785224915
# /videorec/frame
# /minibee/data
# 0.51178121566772
# /videorec/frame
# /minibee/data
# 0.50750821828842
# /videorec/frame
# /minibee/data
# 0.50543278455734
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.5049444437027
# /videorec/frame
# /minibee/data
# 0.5050665140152
# /videorec/frame
# /minibee/data
# 0.50384569168091
# /videorec/frame
# /minibee/data
# 0.50177025794983
# /videorec/frame
# /minibee/data
# 0.50225859880447
# /videorec/frame
# /minibee/data
# 0.50262480974197
# /videorec/frame
# /minibee/data
# 0.50262480974197
# /videorec/frame
# /minibee/data
# 0.50177025794983
# /videorec/frame
# /minibee/data
# 0.50726407766342
# /videorec/frame
# /minibee/data
# 0.5049444437027
# /videorec/frame
# /minibee/data
# 0.5048223733902
# /videorec/frame
# /minibee/data
# 0.50872910022736
# /videorec/frame
# /minibee/data
# 0.50848489999771
# /videorec/frame
# /minibee/data
# 0.50970578193665
# /videorec/frame
# /minibee/data
# 0.51165914535522
# /videorec/frame
# /minibee/data
# 0.51251375675201
# /videorec/frame
# /minibee/data
# 0.51239162683487
# /videorec/frame
# /minibee/data
# 0.51178121566772
# /videorec/frame
# /minibee/data
# 0.51190328598022
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.51312416791916
# /videorec/frame
# /minibee/data
# 0.51312416791916
# /videorec/frame
# /minibee/data
# 0.51544380187988
# /videorec/frame
# /minibee/data
# 0.51434499025345
# /videorec/frame
# /minibee/data
# 0.50225859880447
# /videorec/frame
# /minibee/data
# 0.50006103515625
# /videorec/frame
# /minibee/data
# 0.50006103515625
# /videorec/frame
# /minibee/data
# 0.49822977185249
# /videorec/frame
# /minibee/data
# 0.49664264917374
# /videorec/frame
# /minibee/data
# 0.49554389715195
# /videorec/frame
# /minibee/data
# 0.49652057886124
# /videorec/frame
# /minibee/data
# 0.49713099002838
# /videorec/frame
# /minibee/data
# 0.49761933088303
# /videorec/frame
# /minibee/data
# 0.49749726057053
# /videorec/frame
# /minibee/data
# 0.49786350131035
# /videorec/frame
# /minibee/data
# 0.50433403253555
# /videorec/frame
# /minibee/data
# 0.51129287481308
# /videorec/frame
# /minibee/data
# 0.50653153657913
# /videorec/frame
# /minibee/data
# 0.51080453395844
# /videorec/frame
# /minibee/data
# 0.5134904384613
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.51593214273453
# /videorec/frame
# /minibee/data
# 0.51703089475632
# /videorec/frame
# /minibee/data
# 0.51629835367203
# /videorec/frame
# /minibee/data
# 0.51617628335953
# /videorec/frame
# /minibee/data
# 0.51593214273453
# /videorec/frame
# /minibee/data
# 0.51593214273453
# /videorec/frame
# /minibee/data
# 0.51581001281738
# /videorec/frame
# /minibee/data
# 0.51666462421417
# /videorec/frame
# /minibee/data
# 0.51678669452667
# /videorec/frame
# /minibee/data
# 0.52057135105133
# /videorec/frame
# /minibee/data
# 0.50433403253555
# /videorec/frame
# /minibee/data
# 0.49603223800659
# /videorec/frame
# /minibee/data
# 0.48968380689621
# /videorec/frame
# /minibee/data
# 0.4928580224514
# /videorec/frame
# /minibee/data
# 0.49468928575516
# /videorec/frame
# /minibee/data
# 0.49493345618248
# /videorec/frame
# /minibee/data
# 0.49359053373337
# /videorec/frame
# /minibee/data
# 0.49432304501534
# /videorec/frame
# /minibee/data
# 0.49529972672462
# /videorec/frame
# /minibee/data
# 0.49432304501534
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.49554389715195
# /videorec/frame
# /minibee/data
# 0.49273592233658
# /minibee/data
# 0.50311315059662
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.50347942113876
# /videorec/frame
# /minibee/data
# 0.50750821828842
# /videorec/frame
# /minibee/data
# 0.51581001281738
# /videorec/frame
# /minibee/data
# 0.52044928073883
# /videorec/frame
# /minibee/data
# 0.52252471446991
# /videorec/frame
# /minibee/data
# 0.51959466934204
# /videorec/frame
# /minibee/data
# 0.51703089475632
# /videorec/frame
# /minibee/data
# 0.51605421304703
# /videorec/frame
# /minibee/data
# 0.51617628335953
# /videorec/frame
# /minibee/data
# 0.51617628335953
# /videorec/frame
# /minibee/data
# 0.51849591732025
# /videorec/frame
# /minibee/data
# 0.52057135105133
# /videorec/frame
# /minibee/data
# 0.51300209760666
# /videorec/frame
# /minibee/data
# 0.50726407766342
# /videorec/frame
# /minibee/data
# 0.50360149145126
# /videorec/frame
# /minibee/data
# 0.49676474928856
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.4906604886055
# /videorec/frame
# /minibee/data
# 0.4928580224514
# /minibee/data
# 0.49420094490051
# /videorec/frame
# /minibee/data
# 0.4950555562973
# /videorec/frame
# /minibee/data
# 0.49481138586998
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.49529972672462
# /videorec/frame
# /minibee/data
# 0.4951776266098
# /videorec/frame
# /minibee/data
# 0.49188134074211
# /videorec/frame
# /minibee/data
# 0.50384569168091
# /videorec/frame
# /minibee/data
# 0.50262480974197
# /videorec/frame
# /minibee/data
# 0.5093395113945
# /videorec/frame
# /minibee/data
# 0.52447807788849
# /videorec/frame
# /minibee/data
# 0.52240264415741
# /videorec/frame
# /minibee/data
# 0.52167010307312
# /videorec/frame
# /minibee/data
# 0.51837384700775
# /videorec/frame
# /minibee/data
# 0.51788550615311
# /videorec/frame
# /minibee/data
# 0.51678669452667
# /videorec/frame
# /minibee/data
# 0.51654255390167
# /videorec/frame
# /minibee/data
# 0.51715296506882
# /videorec/frame
# /minibee/data
# 0.51849591732025
# /videorec/frame
# /minibee/data
# 0.51812964677811
# /videorec/frame
# /minibee/data
# 0.51544380187988
# /videorec/frame
# /minibee/data
# 0.50567698478699
# /videorec/frame
# /minibee/data
# 0.49786350131035
# /videorec/frame
# /minibee/data
# 0.49407887458801
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.49383470416069
# /videorec/frame
# /minibee/data
# 0.49432304501534
# /videorec/frame
# /minibee/data
# 0.49383470416069
# /videorec/frame
# /minibee/data
# 0.49359053373337
# /videorec/frame
# /minibee/data
# 0.49395677447319
# /videorec/frame
# /minibee/data
# 0.49371260404587
# /videorec/frame
# /minibee/data
# 0.49188134074211
# /videorec/frame
# /minibee/data
# 0.48980587720871
# /videorec/frame
# /minibee/data
# 0.49578806757927
# /videorec/frame
# /minibee/data
# 0.50616532564163
# /videorec/frame
# /minibee/data
# 0.51971673965454
# /videorec/frame
# /minibee/data
# 0.51983886957169
# /videorec/frame
# /minibee/data
# 0.52398973703384
# /videorec/frame
# /minibee/data
# 0.52154803276062
# /videorec/frame
# /minibee/data
# 0.51556587219238
# /videorec/frame
# /minibee/data
# 0.51751923561096
# /videorec/frame
# /minibee/data
# 0.51678669452667
# /videorec/frame
# /minibee/data
# 0.51764130592346
# /videorec/frame
# /minibee/data
# 0.5188621878624
# /videorec/frame
# /minibee/data
# 0.52008301019669
# /videorec/frame
# /minibee/data
# 0.52191430330276
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.5235013961792
# /videorec/frame
# /minibee/data
# 0.50860702991486
# /videorec/frame
# /minibee/data
# 0.49261385202408
# /videorec/frame
# /minibee/data
# 0.49029421806335
# /videorec/frame
# /minibee/data
# 0.49139299988747
# /videorec/frame
# /minibee/data
# 0.49591013789177
# /videorec/frame
# /minibee/data
# 0.49627640843391
# /videorec/frame
# /minibee/data
# 0.49407887458801
# /videorec/frame
# /minibee/data
# 0.4951776266098
# /videorec/frame
# /minibee/data
# 0.49664264917374
# /videorec/frame
# /minibee/data
# 0.49664264917374
# /videorec/frame
# /minibee/data
# 0.4973751604557
# /videorec/frame
# /minibee/data
# 0.49676474928856
# /videorec/frame
# /minibee/data
# 0.4951776266098
# /videorec/frame
# /minibee/data
# 0.49005004763603
# /videorec/frame
# /minibee/data
# 0.50763034820557
# /videorec/frame
# /minibee/data
# 0.50970578193665
# /videorec/frame
# /minibee/data
# 0.51568794250488
# /videorec/frame
# /minibee/data
# 0.52093762159348
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.52582103013992
# /videorec/frame
# /minibee/data
# 0.52130389213562
# /videorec/frame
# /minibee/data
# 0.51861798763275
# /videorec/frame
# /minibee/data
# 0.51751923561096
# /videorec/frame
# /minibee/data
# 0.51703089475632
# /videorec/frame
# /minibee/data
# 0.51849591732025
# /videorec/frame
# /minibee/data
# 0.52008301019669
# /videorec/frame
# /minibee/data
# 0.5236234664917
# /videorec/frame
# /minibee/data
# 0.51178121566772
# /videorec/frame
# /minibee/data
# 0.50555485486984
# /videorec/frame
# /minibee/data
# 0.490782558918
# /videorec/frame
# /minibee/data
# 0.49188134074211
# /videorec/frame
# /minibee/data
# 0.49212551116943
# /videorec/frame
# /minibee/data
# 0.49310219287872
# /videorec/frame
# /minibee/data
# 0.49407887458801
# /videorec/frame
# /minibee/data
# 0.49334636330605
# /videorec/frame
# /minibee/data
# 0.49273592233658
# /videorec/frame
# /minibee/data
# 0.49212551116943
# /videorec/frame
# /minibee/data
# 0.49151507019997
# /videorec/frame
# /minibee/data
# 0.4928580224514
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.50006103515625
# /videorec/frame
# /minibee/data
# 0.51068246364594
# /videorec/frame
# /minibee/data
# 0.51642048358917
# /videorec/frame
# /minibee/data
# 0.5233793258667
# /videorec/frame
# /minibee/data
# 0.52704185247421
# /videorec/frame
# /minibee/data
# 0.52118176221848
# /videorec/frame
# /minibee/data
# 0.51849591732025
# /videorec/frame
# /minibee/data
# 0.51825171709061
# /videorec/frame
# /minibee/data
# 0.51800757646561
# /videorec/frame
# /minibee/data
# 0.51874005794525
# /videorec/frame
# /minibee/data
# 0.51837384700775
# /videorec/frame
# /minibee/data
# 0.51837384700775
# /videorec/frame
# /minibee/data
# 0.51800757646561
# /videorec/frame
# /minibee/data
# 0.51776337623596
# /videorec/record/start
# started
# /minibee/data
# 0.52533268928528
# /videorec/frame
# /minibee/data
# 0.52301305532455
# /videorec/frame
# /minibee/data
# 0.52191430330276
# /videorec/frame
# /minibee/data
# 0.52008301019669
# /videorec/frame
# /minibee/data
# 0.52276891469955
# /videorec/frame
# /minibee/data
# 0.52069342136383
# /videorec/frame
# /minibee/data
# 0.51959466934204
# /videorec/frame
# /minibee/data
# 0.51666462421417
# /videorec/frame
# /minibee/data
# 0.51983886957169
# /videorec/frame
# /minibee/data
# 0.51300209760666
# /videorec/frame
# /minibee/data
# 0.51080453395844
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.50579905509949
# /videorec/frame
# /minibee/data
# 0.50787448883057
# /videorec/frame
# /minibee/data
# 0.50738614797592
# /videorec/frame
# /minibee/data
# 0.50885117053986
# /videorec/frame
# /minibee/data
# 0.50592112541199
# /videorec/frame
# /minibee/data
# 0.50115978717804
# /videorec/frame
# /minibee/data
# 0.49688681960106
# /videorec/frame
# /minibee/data
# 0.49749726057053
# /videorec/frame
# /minibee/data
# 0.50347942113876
# /videorec/frame
# /minibee/data
# 0.51458919048309
# /videorec/frame
# /minibee/data
# 0.50970578193665
# /videorec/frame
# /minibee/data
# 0.51495546102524
# /videorec/frame
# /minibee/data
# 0.52020508050919
# /videorec/frame
# /minibee/data
# 0.52105969190598
# /videorec/frame
# /minibee/data
# 0.52179223299026
# /videorec/frame
# /minibee/data
# 0.52044928073883
# /videorec/frame
# /minibee/data
# 0.51874005794525
# /videorec/frame
# /minibee/data
# 0.51324623823166
# /videorec/frame
# /minibee/data
# 0.51129287481308
# /videorec/frame
# /minibee/data
# 0.51031619310379
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.51263582706451
# /videorec/frame
# /minibee/data
# 0.50970578193665
# /videorec/frame
# /minibee/data
# 0.51141494512558
# /videorec/frame
# /minibee/data
# 0.51300209760666
# /videorec/frame
# /minibee/data
# 0.5134904384613
# /videorec/frame
# /minibee/data
# 0.5136125087738
# /videorec/frame
# /minibee/data
# 0.5093395113945
# /videorec/frame
# /minibee/data
# 0.50640946626663
# /videorec/frame
# /minibee/data
# 0.50384569168091
# /videorec/frame
# /minibee/data
# 0.50054937601089
# /videorec/frame
# /minibee/data
# 0.50628739595413
# /videorec/frame
# /minibee/data
# 0.51483333110809
# /videorec/frame
# /minibee/data
# 0.50787448883057
# /videorec/frame
# /minibee/data
# 0.51422291994095
# /videorec/frame
# /minibee/data
# 0.52044928073883
# /videorec/frame
# /minibee/data
# 0.52154803276062
# /videorec/frame
# /minibee/data
# 0.52252471446991
# /videorec/frame
# /minibee/data
# 0.52411180734634
# /videorec/frame
# /minibee/data
# 0.52008301019669
# /videorec/frame
# /minibee/data
# 0.51153707504272
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.51568794250488
# /videorec/frame
# /minibee/data
# 0.50518864393234
# /videorec/frame
# /minibee/data
# 0.50250273942947
# /videorec/frame
# /minibee/data
# 0.50177025794983
# /videorec/frame
# /minibee/data
# 0.5049444437027
# /videorec/frame
# /minibee/data
# 0.51239162683487
# /videorec/frame
# /minibee/data
# 0.50372362136841
# /videorec/frame
# /minibee/data
# 0.50408983230591
# /videorec/frame
# /minibee/data
# 0.51056039333344
# /videorec/frame
# /minibee/data
# 0.50775241851807
# /videorec/frame
# /minibee/data
# 0.50836282968521
# /videorec/frame
# /minibee/data
# 0.50445610284805
# /videorec/frame
# /minibee/data
# 0.49835184216499
# /videorec/frame
# /minibee/data
# 0.51019412279129
# /videorec/frame
# /minibee/data
# 0.49383470416069
# /videorec/frame
# /minibee/data
# 0.49908435344696
# /videorec/frame
# /minibee/data
# 0.51043826341629
# /videorec/frame
# /minibee/data
# 0.51605421304703
# /videorec/frame
# /minibee/data
# 0.52008301019669
# /videorec/frame
# /minibee/data
# 0.52289098501205
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.52301305532455
# /videorec/frame
# /minibee/data
# 0.51483333110809
# /videorec/frame
# /minibee/data
# 0.5134904384613
# /videorec/frame
# /minibee/data
# 0.51593214273453
# /videorec/frame
# /minibee/data
# 0.50042730569839
# /videorec/frame
# /minibee/data
# 0.49188134074211
# /videorec/frame
# /minibee/data
# 0.49542179703712
# /videorec/frame
# /minibee/data
# 0.50567698478699
# /videorec/frame
# /minibee/data
# 0.51544380187988
# /videorec/frame
# /minibee/data
# 0.51544380187988
# /videorec/frame
# /minibee/data
# 0.51422291994095
# /videorec/frame
# /minibee/data
# 0.5136125087738
# /videorec/frame
# /minibee/data
# 0.50799655914307
# /videorec/frame
# /minibee/data
# 0.50408983230591
# /videorec/frame
# /minibee/data
# 0.50140398740768
# /videorec/frame
# /minibee/data
# 0.509217441082
# /videorec/frame
# /minibee/data
# 0.50750821828842
# /videorec/frame
# /minibee/data
# 0.49774143099785
# /videorec/frame
# /videorec/frame
# /minibee/data
# 0.50824075937271
# /videorec/frame
# /minibee/data
# 0.51617628335953
# /videorec/frame
# /minibee/data
# 0.52081555128098
# /videorec/frame
# /minibee/data
# 0.52289098501205
# /videorec/frame
# /minibee/data
# 0.52460014820099
# /videorec/frame
# /minibee/data
# 0.52594310045242
# 0.210352778435

# %%
maxScale = np.max([np.max(abs(x)) for x in gestures])
maxScale
# Out:
# 1.0

# %%
figsize(20,6)
for i in arange(gestures.shape[0]):
    figure(i)
    plot(gestures[i])

# %%
def generateInternalWeights(nInternalUnits, connectivity):
    success = False
    internalWeights = 0
    while success == False:
        try:
            internalWeights = np.random.randn(nInternalUnits,nInternalUnits) * (np.random.random((nInternalUnits,nInternalUnits)) < connectivity)
            specRad = abs(np.linalg.eig(internalWeights)[0][0])
            if (specRad > 0):
                internalWeights = internalWeights / specRad
                success = True
        except e:
            print(e)
    return internalWeights

# %%
np.random.random(np.random.random(net['p']['N'], 3))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-426-2a477d774230> in <module>()
# ----> 1 np.random.random((np.random.random(net['p']['N'], 3)))
#
# mtrand.pyx in mtrand.RandomState.random_sample (numpy/random/mtrand/mtrand.c:15511)()
#
# TypeError: random_sample() takes at most 1 positional argument (2 given)

# %%
(np.random.rand(net['p']['N'], 3) - 0.5) *  (np.random.random(np.random.rand(net['p']['N'], 3)) < 0.3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-423-7ed9a52ad098> in <module>()
# ----> 1 (np.random.rand(net['p']['N'], 3) - 0.5) *  (np.random.random(np.random.rand(net['p']['N'], 3)) < 0.3)
#
# mtrand.pyx in mtrand.RandomState.random_sample (numpy/random/mtrand/mtrand.c:15541)()
#
# mtrand.pyx in mtrand.cont0_array (numpy/random/mtrand/mtrand.c:6141)()
#
# ValueError: sequence too large; cannot be greater than 32

# %%
def makeClassifierNetwork(p):
    Netconnectivity = 1
    if p['N'] > 20:
        Netconnectivity = 10.0/p['N'];
    WstarRaw = generateInternalWeights(p['N'], Netconnectivity)
    WinRaw = 2 * (np.random.rand(p['N'], 3) - 0.5) *  (np.random.random((p['N'], 3)) < 0.5)
    WbiasRaw = 2 * (np.random.rand(p['N'], 1) - 0.5)

    #Scale raw weights     
    Wstar = p['NetSR'] * WstarRaw;
    W = Wstar
    Win = p['NetinpScaling'] * WinRaw;
    Wbias = p['BiasScaling'] * WbiasRaw;  
    I = np.eye(p['N'])
    xCollector = np.zeros((p['N'], p['learnLength']))
    pCollector = np.zeros((3, p['learnLength']))
    x = np.zeros((p['N'],1))
    
    allTrainxArgs = np.zeros((p['N'] + 1, 0));
    allTrainOldxArgs = np.zeros((p['N'], 0));
    allTrainWtargets = np.zeros((p['N'], 0));
    allTrainOuts = np.zeros((3, 0));
    patternRs =  np.zeros((1, p['patts'].size), dtype=np.object)
    
    for i_pattern in range(p['patts'].size):
        print('Observing pattern ', i_pattern)
        patt = p['patts'][i_pattern]
        xCollector = np.zeros((p['N'] + 1, p['learnLength']));
        xOldCollector = np.zeros((p['N'], p['learnLength']));
        WTargetCollector = np.zeros((p['N'], p['learnLength']));
        pCollector = np.zeros((3, p['learnLength']));
        x = np.zeros((p['N'], 1));

        for n in range(p['washoutLength'] + p['learnLength']):
            u = patt.take(n, mode='wrap', axis=0)
            xOld = x
            Wtarget = (Wstar.dot(x)) + vstack(Win.dot(u))
            x = ((1.0-p['LR']) * xOld) + (p['LR'] * tanh(Wtarget + Wbias))
            if n >= p['washoutLength']:
                xCollector[:, n - p['washoutLength']] = np.concatenate((x[:,0], np.array([1])))
                xOldCollector[:, n - p['washoutLength']] = xOld[:,0]
                WTargetCollector[:, n - p['washoutLength']] = Wtarget[:,0]
                pCollector[:, n - p['washoutLength']] = u
            uOld = u
        
        R = xCollector[0:-1].dot(xCollector[0:-1].T) / p['learnLength']
        patternRs[0,i_pattern] = R
        allTrainxArgs = np.concatenate((allTrainxArgs, xCollector), axis=1)
        allTrainOldxArgs = np.concatenate((allTrainOldxArgs, xOldCollector), axis=1)
        allTrainOuts = np.concatenate((allTrainOuts, pCollector), axis=1)
        allTrainWtargets = np.concatenate((allTrainWtargets, WTargetCollector), axis=1)
        print("Done")

    return locals()

params = {'N':100, 'NetSR':1.1, 'NetinpScaling':1.5,'BiasScaling':0.3,
         'washoutLength':50, 'learnLength':2000, 
          'LR': 0.1,
          'patts':gestures[[0,7,9]]
         }

net = makeClassifierNetwork(params)
# Out:
# Observing pattern  0
# Done
# Observing pattern  1
# Done
# Observing pattern  2
# Done

# %%
figsize(20,6)
plot(net['allTrainxArgs'].T[:])
None

# %%
def computeConceptor(p, net, i_pattern, alpha):
#     print('Computing conceptor, alpha: ', alpha)
    Cs = np.zeros((4, 1), dtype=np.object)
    R = net['patternRs'][0,i_pattern]
    [U,s,V] = svd(R)
    S = diag(s)
    Snew = (S * linalg.inv(S + pow(alpha, -2) * np.eye(p['N'])))

    C =  U.dot(Snew).dot(U.conj().T);
    Cs[0,0] = C
    Cs[1,0] = U
    Cs[2,0] = diag(Snew)
    Cs[3,0] = diag(S)

    return Cs

def testConceptor(net, cNet, recallTestLength):
    trials = 1
    attens = np.zeros(trials)
    p = net['p']
    C = cNet[0,0]
    for i_trial in range(trials):
        x_CTestPL = np.zeros((p['N'], recallTestLength))
        z_CTestPL = np.zeros((p['N'], recallTestLength))
#         p_CTestPL = np.zeros((1, recallTestLength))
        x = 0.5 * np.random.randn(p['N'],1)
        z = x
        for n in range(recallTestLength + p['washoutLength']):
            xOld = x
            Wtarget = (net['W'].dot(x))
            z = ((1.0-p['LR']) * xOld) + (p['LR'] * tanh(Wtarget + net['Wbias']))
            x = C.dot(z)
            xPrev = x
            if (n > p['washoutLength']):
                x_CTestPL[:,n-p['washoutLength']] = x.T
                z_CTestPL[:,n-p['washoutLength']] = z.T
#                 p_CTestPL[:,n-p['washoutLength']] = cNet['net']['Wout'].dot(np.concatenate((x[:,0], np.array([1]))))

#         attenuation = np.mean(pow(np.sum(z_CTestPL[:,:] - x_CTestPL[:,:], axis=1),2)) / np.mean(pow(np.sum(z_CTestPL[:,:], axis=1),2))
        attenuation = np.mean(pow(np.linalg.norm(z_CTestPL[:,:] - x_CTestPL[:,:], axis=1),2)) / np.mean(pow(np.linalg.norm(z_CTestPL[:,:], axis=1),2))
        attens[i_trial] = attenuation
        
    return np.mean(attens)

def fitnessf(aperture, *args):
    print('Pattern: ', args[0])
    cnet = computeConceptor(net['p'], net, args[0], aperture)
    atten = testConceptor(net, cnet, 300)
    return atten

# %%
import scipy.optimize
apertures = [sp.optimize.fminbound(fitnessf, 0,1000,  disp=3, xtol=1, args = (x,)) 
             for x in np.arange(net['p']['patts'].shape[0])]

#store conceptors with calculated apertures
patternCs = np.zeros(len(apertures), dtype=np.object)
for i_patt in range(patternCs.size):
    patternCs[i_patt] = computeConceptor(net['p'], net, i_patt, apertures[i_patt])
# Out:
# Pattern:  0
#
#  Func-count     x          f(x)          Procedure
#     1        381.966    0.0020251        initial
# Pattern:  0
#     2        618.034   0.00189875        golden
# Pattern:  0
#     3        763.932    0.0018117        golden
# Pattern:  0
#     4        854.102   0.00181105        golden
# Pattern:  0
#     5        810.455   0.00183087        parabolic
# Pattern:  0
#     6         909.83   0.00171969        golden
# Pattern:  0
#     7        944.272   0.00167376        golden
# Pattern:  0
#     8        965.558   0.00171397        golden
# Pattern:  0
#     9        938.581   0.00164851        parabolic
# Pattern:  0
#    10        927.599   0.00177569        golden
# Pattern:  0
#    11        934.387   0.00166874        golden
# Pattern:  0
#    12        939.059   0.00171336        parabolic
# Pattern:  0
#    13        938.248   0.00171143        parabolic
#
# Optimization terminated successfully;
# The returned value satisfies the termination criteria
# (using xtol =  1 )
# Pattern:  1
#
#  Func-count     x          f(x)          Procedure
#     1        381.966   0.00119509        initial
# Pattern:  1
#     2        618.034   0.00100921        golden
# Pattern:  1
#     3        763.932  0.000914318        golden
# Pattern:  1
#     4        854.102  0.000887317        golden
# Pattern:  1
#     5        909.724  0.000848273        parabolic
# Pattern:  1
#     6        944.207  0.000847436        golden
# Pattern:  1
#     7        928.579  0.000850415        parabolic
# Pattern:  1
#     8        965.518  0.000794809        golden
# Pattern:  1
#     9        978.689  0.000795299        golden
# Pattern:  1
#    10        971.847  0.000790409        parabolic
# Pattern:  1
#    11        972.181   0.00084333        parabolic
# Pattern:  1
#    12        971.514  0.000812502        parabolic
#
# Optimization terminated successfully;
# The returned value satisfies the termination criteria
# (using xtol =  1 )
# Pattern:  2
#
#  Func-count     x          f(x)          Procedure
#     1        381.966  0.000607754        initial
# Pattern:  2
#     2        618.034   0.00052796        golden
# Pattern:  2
#     3        763.932  0.000538701        golden
# Pattern:  2
#     4        656.826  0.000533167        parabolic
# Pattern:  2
#     5        527.864   0.00055492        golden
# Pattern:  2
#     6        583.592  0.000548642        golden
# Pattern:  2
#     7        632.851  0.000529115        golden
# Pattern:  2
#     8        608.838  0.000567257        parabolic
# Pattern:  2
#     9        623.694   0.00054157        golden
# Pattern:  2
#    10        614.522  0.000561969        golden
# Pattern:  2
#    11        620.196  0.000545662        golden
# Pattern:  2
#    12        616.692  0.000550819        golden
# Pattern:  2
#    13         618.86  0.000538346        golden
# Pattern:  2
#    14        617.522  0.000542814        golden
# Pattern:  2
#    15        618.367  0.000554317        golden
#
# Optimization terminated successfully;
# The returned value satisfies the termination criteria
# (using xtol =  1 )

# %%
apertures
# Out:
# [938.58130729499078, 971.84722036581275, 618.03398874989477]

# %%
patternCs.shape
# Out:
# (3,)

# %%
import scipy.spatial.distance as dist


def plotConceptorPatterns(net, cNet, recallTestLength):
    #calc negative evidence
    def conceptorOr(C,B,N):
        I = np.eye(N)
        return linalg.inv(I + linalg.inv(C.dot(linalg.inv(1.0-C)) + B.dot(linalg.inv(1.0-B))))
    patternCsNeg = np.zeros(len(apertures), dtype=np.object)

    for i_c in arange(net['p']['patts'].size):
        idxs = np.delete(arange(net['p']['patts'].size), i_c)
        Cneg = conceptorOr(patternCs[idxs[0]][0,0], patternCs[idxs[1]][0,0], net['p']['N'])
        for i_idx in idxs[2:]:
            Cneg = conceptorOr(Cneg, patternCs[i_idx][0,0], net['p']['N'])
        Cneg = 1.0 - Cneg
        patternCsNeg[i_c] = Cneg

#     x_CTestPL = np.zeros((3, recallTestLength, p['patts'].size))
#     p_CTestPL = np.zeros((1, recallTestLength, p['patts'].size))
    cx_CTestPL = np.zeros((net['p']['patts'].size,recallTestLength))
    pat_CTestPL = np.zeros((3,recallTestLength))
    
    for i_pattern in range(net['p']['patts'].size):
        patt = net['p']['patts'][i_pattern]
        x = np.zeros((net['p']['N'],1))
        for n in range(recallTestLength + net['p']['washoutLength']):
            u = patt.take(n, mode='wrap', axis=0)
            xOld = x
            Wtarget = (net['Wstar'].dot(x)) + vstack((net['Win'].dot(u)))
            x = ((1.0-net['p']['LR']) * xOld) + (net['p']['LR'] * tanh(Wtarget + net['Wbias']))
            if (n > net['p']['washoutLength']):
                pat_CTestPL[:,n-net['p']['washoutLength'] ] = u
                
                for i_ev in range(net['p']['patts'].size):
                    C = patternCs[i_ev][0,0]
                    C2 = patternCsNeg[i_ev]
                    cx = x.T.dot(C.dot(x))
                    cx2 = x.T.dot(C2.dot(x))
                    cx_CTestPL[i_ev,n-net['p']['washoutLength']] = cx + cx2
                    

        ax = subplot(net['p']['patts'].size * 2, 2, i_pattern*2 + 1)
#         ax.set_title("Sample " + str(suboff/2) + ", pattern: " + str(i_pattern) )
#         plot([p['patts'][i_pattern](x) for x in arange(recallTestLength)])
        plot(pat_CTestPL.T)
        ax = subplot(net['p']['patts'].size * 2, 2, i_pattern*2 + 2)
        for i_plot in range(net['p']['patts'].size):
            plot(cx_CTestPL[i_plot,1:].T, label=i_plot)
        ax.legend()
#         classificationScore = np.sum(cx_CTestPL[i_pattern] > cx_CTestPL[1 - i_pattern]) / cx_CTestPL[0].size
#         separation = dist.euclidean(cx_CTestPL[i_pattern],cx_CTestPL[1-i_pattern])
#         print("Pattern ", str(i_pattern), " classification score: ", classificationScore, ", separation: ", separation)
        #testing

    return locals()

# %%
figsize(20,120)
plotConceptorPatterns(net, patternCs, 100)
None
